# %% [markdown]
# Télécharger un ensemble de données d'images de fleurs étiquetées, telles que
# l'ensemble de données Iris

# %%
from sklearn.datasets import load_iris
data = load_iris()
print(data['DESCR'])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %% [markdown]
# Importer les bibliothèques nécessaires, telles que TensorFlow, Keras et
# NumPy

# %%
import tensorflow as tf
import numpy as np
import keras as K
print('import successfull')
# Out:
# import successfull

# %% [markdown]
# Charger les images dans un tableau NumPy et normaliser les valeurs des pixels
# de 0 à 1

# %%
rawData = np.array(data['data']) 
normalizedData = (rawData - rawData.min(axis=0)) / (rawData.max(axis=0) - rawData.min(axis=0))

# %% [markdown]
# Diviser les données en ensembles d'entraînement et de test

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(normalizedData, data['target'], test_size=0.2, random_state=42)

# %% [markdown]
# Créer un modèle de réseau neuronal avec Keras en utilisant une architecture
# simple, telle qu'un réseau de neurones à une couche cachée

# %%
model = K.models.Sequential()
model.add(K.layers.Dense(10, activation='relu', input_shape=(4,)))
model.add(K.layers.Dense(10, activation='relu'))
model.add(K.layers.Dense(3, activation='softmax'))

# %% [markdown]
# Compiler le modèle avec une fonction de perte, un optimiseur et une métrique.

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Entraîner le modèle sur l'ensemble d'entraînement et évaluer sa précision sur
# l'ensemble de test

# %%
model.fit(x_train, y_train, epochs=100, batch_size=10, verbose=1)
accuracy = model.evaluate(x_test, y_test, verbose=1)
print('Accuracy: %.2f' % (accuracy[1]*100))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1058 - accuracy: 0.9750
# Epoch 2/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1063 - accuracy: 0.9583
# Epoch 3/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1045 - accuracy: 0.9667
# Epoch 4/100
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1050 - accuracy: 0.9667
# Epoch 5/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1024 - accuracy: 0.9750
# Epoch 6/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1032 - accuracy: 0.9667
# Epoch 7/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9750
# Epoch 8/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9750
# Epoch 9/100
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1006 - accuracy: 0.9667
# Epoch 10/100
# ...
